# %% [markdown]
# <a href="https://colab.research.google.com/github/SorrowAddict/SK-FLY-AI/blob/main/AI_Learning/Week-01_Python/231218_Python_00_%EA%B8%B0%EB%B3%B8_%EC%A7%80%EC%8B%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 파이썬 기본 예제

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# ## 웹에서 이미지를 요청 및 시각화 예제

# %%
import requests
from PIL import Image
from io import BytesIO

# %%
response = requests.get('http://www.naver.com')
print(response.text)
# Out:
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description"
# ...

# %%
response = requests.get('https://d2zp5xs5cp8zlg.cloudfront.net/image-83814-800.jpg')

# %% [markdown]
# ### 16진수로 변환한 이미지 데이터

# %%
response.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\x07\x07\x07\x07\x07\x07\x08\t\t\x08\x0b\x0c\x0b\x0c\x0b\x10\x0f\x0e\x0e\x0f\x10\x19\x12\x13\x12\x13\x12\x19%\x17\x1b\x17\x17\x1b\x17%!(!\x1e!(!;/))/;E:7:ESJJSici\x89\x89\xb8\x01\x07\x07\x07\x07\x07\x07\x08\t\t\x08\x0b\x0c\x0b\x0c\x0b\x10\x0f\x0e\x0e\x0f\x10\x19\x12\x13\x12\x13\x12\x19%\x17\x1b\x17\x17\x1b\x17%!(!\x1e!(!;/))/;E:7:ESJJSici\x89\x89\xb8\xff\xc2\x00\x11\x08\x02\x16\x03 \x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x003y\xfd\x11\x05\xa9jL\xd9X\xe8K\xdce\xb3\xad\x16\xa9\xbcpc\xa6\xc5\x97\x19\xe6\xe5R\xda\x94\xc1\xd2=\x8d\x11sXY\x8b\x1dj\xc9n\x8eI\xebuR/\xc5f\xdd\xac\xc4\xcc\x91h\xb9\x16\xe9:\xf4\xb9\xd5\xb4\'LX\xee\xee+\xd3\x
# ...

# %% [markdown]
# ## 바이트 데이터를 메모리 데이터로 변환 후 오픈

# %%
image = Image.open(BytesIO(response.content))

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x534>

# %% [markdown]
# ## 한 번에 requests.get 해서 이미지 컨텐츠를 오픈하는 코드

# %%
Image.open(BytesIO(requests.get('https://d2zp5xs5cp8zlg.cloudfront.net/image-83814-800.jpg').content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x534>

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.4/227.4 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 11.2 MB/s eta 0:00:00
# ...
