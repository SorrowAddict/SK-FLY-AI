# %% [markdown]
# <a href="https://colab.research.google.com/github/SorrowAddict/SK-FLY-AI/blob/main/AI_Learning/Week-02_Machine_Learning/231229_01_Cats_vs_Dogs_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --no-check-certificate \
https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
-O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2023-12-29 00:19:08--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.97.207, 142.251.170.207, 173.194.174.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.97.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M  20.9MB/s    in 3.1s
#
# 2023-12-29 00:19:12 (20.9 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
import os
import zipfile

local_zip = '/tmp/cats_and_dogs_filtered.zip'

zip_ref = zipfile.ZipFile(local_zip, 'r')

zip_ref.extractall('/tmp')
zip_ref.close()

# %%
# 기본 경로
base_dir = '/tmp/cats_and_dogs_filtered'

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# 훈련에 사용되는 고양이/개 이미지 경로
train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')
print(train_cats_dir)
print(train_dogs_dir)

# 테스트에 사용되는 고양이/개 이미지 경로
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')
print(validation_cats_dir)
print(validation_dogs_dir)
# Out:
# /tmp/cats_and_dogs_filtered/train/cats
# /tmp/cats_and_dogs_filtered/train/dogs
# /tmp/cats_and_dogs_filtered/validation/cats
# /tmp/cats_and_dogs_filtered/validation/dogs

# %%
train_cat_fnames = os.listdir( train_cats_dir )
train_dog_fnames = os.listdir( train_dogs_dir )

print(train_cat_fnames[:5])
print(train_dog_fnames[:5])
# Out:
# ['cat.525.jpg', 'cat.852.jpg', 'cat.181.jpg', 'cat.500.jpg', 'cat.398.jpg']
# ['dog.740.jpg', 'dog.602.jpg', 'dog.319.jpg', 'dog.938.jpg', 'dog.294.jpg']

# %%
print('Total training cat images :', len(os.listdir(train_cats_dir)))
print('Total training dog images :', len(os.listdir(train_dogs_dir)))

print('Total validation cat images :', len(os.listdir(validation_cats_dir)))
print('Total validation dog images :', len(os.listdir(validation_dogs_dir)))
# Out:
# Total training cat images : 1000
# Total training dog images : 1000
# Total validation cat images : 500
# Total validation dog images : 500

# %%
# 시각화로 보기
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

nrows, ncols = 4, 4
pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols*3, nrows*3)

pic_index+=8

next_cat_pix = [os.path.join(train_cats_dir, fname)
                for fname in train_cat_fnames[ pic_index-8:pic_index]]

next_dog_pix = [os.path.join(train_dogs_dir, fname)
                for fname in train_dog_fnames[ pic_index-8:pic_index]]

for i, img_path in enumerate(next_cat_pix+next_dog_pix):
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off')

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
# 3. 모델 구성
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(150, 150, 3)),
    tf.keras.layers.Dense(512, activation=tf.nn.relu),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# 4. 모델 컴파일
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# 이미지 데이터 전처리
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator( rescale = 1.0/255. )
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )

train_generator = train_datagen.flow_from_directory(train_dir,
                                                  batch_size=20,
                                                  class_mode='binary',
                                                  target_size=(150, 150))
validation_generator =  test_datagen.flow_from_directory(validation_dir,
                                                       batch_size=20,
                                                       class_mode  = 'binary',
                                                       target_size = (150, 150))

# 5. 모델 훈련
model.fit(train_generator, validation_data=validation_generator, epochs=5)

# 6. 정확도 평가
test_loss, test_acc = model.evaluate(x_test, y_test)
print('테스트 정확도:', test_acc)

# %%
# # 모델 구성하기
# import tensorflow as tf


# model = tf.keras.models.Sequential([
#   tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)),
#   tf.keras.layers.MaxPooling2D(2,2),
#   tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
#   tf.keras.layers.MaxPooling2D(2,2),
#   tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
#   tf.keras.layers.MaxPooling2D(2,2),
#   tf.keras.layers.Flatten(),
#   tf.keras.layers.Dense(128, activation='relu'),
#   tf.keras.layers.Dense(1, activation='sigmoid')
# ])

# model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 148, 148, 16)      448
#
#  max_pooling2d_9 (MaxPoolin  (None, 74, 74, 16)        0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 72, 72, 32)        4640
#
#  max_pooling2d_10 (MaxPooli  (None, 36, 36, 32)        0
#  ng2D)
#
#  conv2d_11 (Conv2D)          (None, 34, 34, 64)        18496
#
#  max_pooling2d_11 (MaxPooli  (None, 17, 17, 64)        0
#  ng2D)
#
#  flatten_3 (Flatten)         (None, 18496)             0
#
#  dense_6 (Dense)             (None, 128)               2367616
#
#  dense_7 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 2391329 (9.12 MB)
# Trainable params: 2391329 (9.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# VGG16 모델 불러오기 (이미 학습된 가중치를 사용)
vgg16_model = VGG16(weights='imagenet', include_top=False, input_shape=(150, 150, 3))

# VGG16의 합성곱층을 동결
for layer in vgg16_model.layers:
    layer.trainable = False

# 새로운 모델 구성
model = Sequential([
    vgg16_model,
    Flatten(),
    Dense(units=128, activation='relu'),
    Dense(units=1, activation='sigmoid')
])

# 모델 컴파일
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# 모델 요약
model.summary()

# %%
# 모델 컴파일
from tensorflow.keras.optimizers import RMSprop

model.compile(optimizer=RMSprop(learning_rate=0.001),
            loss='binary_crossentropy',
            metrics = ['accuracy'])

# %%
# 이미지 데이터 전처리
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator( rescale = 1.0/255. )
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )

train_generator = train_datagen.flow_from_directory(train_dir,
                                                  batch_size=20,
                                                  class_mode='binary',
                                                  target_size=(150, 150))
validation_generator =  test_datagen.flow_from_directory(validation_dir,
                                                       batch_size=20,
                                                       class_mode  = 'binary',
                                                       target_size = (150, 150))
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
# 모델 피팅
history = model.fit(train_generator,
                    validation_data=validation_generator,
                    steps_per_epoch=100,    #훈련 배치 개수
                    epochs=25,     #훈련횟수
                    validation_steps=50,    #테스트 배치 개수
                    verbose=2)
# Out:
# Epoch 1/25
# 100/100 - 58s - loss: 0.7407 - accuracy: 0.5295 - val_loss: 0.6883 - val_accuracy: 0.6200 - 58s/epoch - 576ms/step
# Epoch 2/25
# 100/100 - 55s - loss: 0.6744 - accuracy: 0.6075 - val_loss: 0.6540 - val_accuracy: 0.5450 - 55s/epoch - 553ms/step
# Epoch 3/25
# 100/100 - 51s - loss: 0.6153 - accuracy: 0.6945 - val_loss: 0.5941 - val_accuracy: 0.6670 - 51s/epoch - 510ms/step
# Epoch 4/25
# 100/100 - 55s - loss: 0.5572 - accuracy: 0.7150 - val_loss: 0.5723 - val_accuracy: 0.7140 - 55s/epoch - 555ms/step
# Epoch 5/25
# 100/100 - 54s - loss: 0.4929 - accuracy: 0.7560 - val_loss: 0.5245 - val_accuracy: 0.7390 - 54s/epoch - 542ms/step
# Epoch 6/25
# 100/100 - 55s - loss: 0.4272 - accuracy: 0.7925 - val_loss: 0.6156 - val_accuracy: 0.7120 - 55s/epoch - 554ms/step
# Epoch 7/25
# 100/100 - 50s - loss: 0.3699 - accuracy: 0.8375 - val_loss: 0.7267 - val_accuracy: 0.6890 - 50s/epoch - 505ms/step
# Epoch 8/25
# 100/100 - 54s - loss: 0.3042 - accuracy: 0.8785 - val_loss: 0.6026 - val_accuracy: 0.7470 - 54s/epoch - 541ms/step
# Epoch 9/25
# 100/100 - 56s - loss: 0.2392 - accuracy: 0.9040 - val_loss: 0.6371 - val_accuracy: 0.7290 - 56s/epoch - 557ms/step
# Epoch 10/25
# 100/100 - 51s - loss: 0.1844 - accuracy: 0.9340 - val_loss: 0.7831 - val_accuracy: 0.7290 - 51s/epoch - 507ms/step
# Epoch 11/25
# 100/100 - 53s - loss: 0.1345 - accuracy: 0.9480 - val_loss: 0.8854 - val_accuracy: 0.7190 - 53s/epoch - 530ms/step
# Epoch 12/25
# 100/100 - 53s - loss: 0.0957 - accuracy: 0.9680 - val_loss: 0.8069 - val_accuracy: 0.7330 - 53s/epoch - 534ms/step
# Epoch 13/25
# 100/100 - 51s - loss: 0.0605 - accuracy: 0.9800 - val_loss: 1.0726 - val_accuracy: 0.7310 - 51s/epoch - 514ms/step
# Epoch 14/25
# 100/100 - 50s - loss: 0.0859 - accuracy: 0.9765 - val_loss: 1.1357 - val_accuracy: 0.7300 - 50s/epoch - 498ms/step
# Epoch 15/25
# 100/100 - 50s - loss: 0.0383 - accuracy: 0.9915 - val_loss: 1.3323 - val_accuracy: 0.7500 - 50s/epoch - 500ms/step
# Epoch 16/25
# 100/100 - 51s - loss: 0.0302 - accuracy: 0.9905 - val_loss: 1.2099 - val_accuracy: 0.7210 - 51s/epoch - 514ms/step
# Epoch 17/25
# 100/100 - 54s - loss: 0.0461 - accuracy: 0.9875 - val_loss: 1.4159 - val_accuracy: 0.7240 - 54s/epoch - 541ms/step
# Epoch 18/25
# 100/100 - 51s - loss: 0.0439 - accuracy: 0.9915 - val_loss: 1.6412 - val_accuracy: 0.7180 - 51s/epoch - 513ms/step
# Epoch 19/25
# 100/100 - 54s - loss: 0.0433 - accuracy: 0.9895 - val_loss: 1.4802 - val_accuracy: 0.7460 - 54s/epoch - 540ms/step
# Epoch 20/25
# 100/100 - 52s - loss: 0.0444 - accuracy: 0.9910 - val_loss: 1.4264 - val_accuracy: 0.7210 - 52s/epoch - 516ms/step
# Epoch 21/25
# 100/100 - 52s - loss: 0.0374 - accuracy: 0.9910 - val_loss: 1.5274 - val_accuracy: 0.7270 - 52s/epoch - 519ms/step
# Epoch 22/25
# 100/100 - 50s - loss: 0.0089 - accuracy: 0.9970 - val_loss: 1.6996 - val_accuracy: 0.7290 - 50s/epoch - 504ms/step
# Epoch 23/25
# 100/100 - 57s - loss: 0.0191 - accuracy: 0.9950 - val_loss: 1.6701 - val_accuracy: 0.7350 - 57s/epoch - 569ms/step
# Epoch 24/25
# 100/100 - 51s - loss: 0.0198 - accuracy: 0.9945 - val_loss: 1.8820 - val_accuracy: 0.7260 - 51s/epoch - 510ms/step
# Epoch 25/25
# 100/100 - 53s - loss: 0.0836 - accuracy: 0.9905 - val_loss: 1.7205 - val_accuracy: 0.7360 - 53s/epoch - 534ms/step

# %%
# 정확도와 손실 확인
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.subplot(2,1,1)
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'g', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()
plt.subplot(2,1,2)
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'g', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
